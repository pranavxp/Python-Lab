# %%
import numpy as np
from sklearn.datasets import load_iris
def euclidean_distance(x1, x2):
    return np.sqrt(np.sum((x1 - x2)**2))

class KNN:
    def __init__(self, k=3):
        self.k = k

    def fit(self, X_train, y_train):
        self.X_train = X_train
        self.y_train = y_train

    def predict(self, X_test):
        predictions = []
        for x in X_test:
            distances = [euclidean_distance(x, x_train) for x_train in self.X_train]
            k_indices = np.argsort(distances)[:self.k]
            k_nearest_labels = [self.y_train[i] for i in k_indices]
            most_common = np.bincount(k_nearest_labels).argmax()
            predictions.append(most_common)
        return predictions


def accuracy_score(y_true, y_pred):
    correct = np.sum(y_true == y_pred)
    total = len(y_true)
    return correct / total

# Load an example dataset (Iris dataset)
data = load_iris()
X = data.data  # Feature data
y = data.target  # Target labels

# Use the entire dataset for training
X_train = X
y_train = y

# Create and train the KNN classifier
knn_model = KNN(k=3)
knn_model.fit(X_train, y_train)

# Make predictions on the entire dataset
y_pred = knn_model.predict(X)

# Calculate accuracy
accuracy = accuracy_score(y, y_pred)
accuracy_percentage = accuracy * 100
print("Accuracy: {:.2f}%".format(accuracy_percentage))


# Print correct and wrong predictions
for i in range(len(y)):
    if y_pred[i] == y[i]:
        print("Sample {}: Correct Prediction | Actual: {}; | Predicted: {}".format( i+1, y[i], y_pred[i]))
    else:
        print("Sample {}: Wrong Prediction | Actual: {}; | Predicted: {}".format(i+1, y[i], y_pred[i]))
# Out:
# Accuracy: 96.00%
# Sample 1: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 2: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 3: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 4: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 5: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 6: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 7: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 8: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 9: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 10: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 11: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 12: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 13: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 14: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 15: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 16: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 17: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 18: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 19: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 20: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 21: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 22: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 23: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 24: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 25: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 26: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 27: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 28: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 29: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 30: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 31: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 32: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 33: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 34: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 35: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 36: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 37: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 38: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 39: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 40: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 41: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 42: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 43: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 44: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 45: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 46: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 47: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 48: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 49: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 50: Correct Prediction | Actual: 0; | Predicted: 0
# Sample 51: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 52: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 53: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 54: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 55: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 56: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 57: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 58: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 59: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 60: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 61: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 62: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 63: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 64: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 65: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 66: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 67: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 68: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 69: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 70: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 71: Wrong Prediction | Actual: 1; | Predicted: 2
# Sample 72: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 73: Wrong Prediction | Actual: 1; | Predicted: 2
# Sample 74: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 75: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 76: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 77: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 78: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 79: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 80: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 81: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 82: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 83: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 84: Wrong Prediction | Actual: 1; | Predicted: 2
# Sample 85: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 86: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 87: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 88: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 89: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 90: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 91: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 92: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 93: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 94: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 95: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 96: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 97: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 98: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 99: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 100: Correct Prediction | Actual: 1; | Predicted: 1
# Sample 101: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 102: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 103: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 104: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 105: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 106: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 107: Wrong Prediction | Actual: 2; | Predicted: 1
# Sample 108: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 109: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 110: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 111: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 112: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 113: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 114: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 115: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 116: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 117: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 118: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 119: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 120: Wrong Prediction | Actual: 2; | Predicted: 1
# Sample 121: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 122: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 123: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 124: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 125: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 126: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 127: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 128: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 129: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 130: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 131: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 132: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 133: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 134: Wrong Prediction | Actual: 2; | Predicted: 1
# Sample 135: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 136: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 137: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 138: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 139: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 140: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 141: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 142: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 143: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 144: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 145: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 146: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 147: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 148: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 149: Correct Prediction | Actual: 2; | Predicted: 2
# Sample 150: Correct Prediction | Actual: 2; | Predicted: 2
